# %%
# Import Dependencies
import os
import pandas as pd
import requests
import json
import pprint
from config import (aqs_api_key)
from config import (email_address)

# https://aqs.epa.gov/aqsweb/documents/data_api.html#signup for api information
pp = pprint.PrettyPrinter(indent = 4)
states_url = "https://aqs.epa.gov/data/api/list/states"
parameters_url = "https://aqs.epa.gov/data/api/list/classes"
sample_data_url = "https://aqs.epa.gov/data/api/dailyData/byState"
p1 = {"email" : email_address, "key" : aqs_api_key}
params = {"email" : email_address, "key" : aqs_api_key, "param" : "44201", 
          "bdate" : "20200101", "edate" : "20200801", "state" : "11"}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-97de11e90bbd> in <module>
#       5 import json
#       6 import pprint
# ----> 7 from config import (aqs_api_key)
#       8 from config import (email_address)
#       9
#
# ModuleNotFoundError: No module named 'config'

# %%
response = requests.get(sample_data_url, params = params)
# response = requests.get(parameters_url, params = p1)
print(response.url)

# %%
state_list = response.json()
pp.pprint(state_list)
# Out:
# {   'Data': [   {   'aqi': None,
#                     'arithmetic_mean': 0.025708,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-01',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 15,
#                     'first_max_value': 0.037,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 31,
#                     'arithmetic_mean': 0.021708,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-01',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 8,
#                     'first_max_value': 0.034,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 31,
#                     'arithmetic_mean': 0.021708,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-01',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 8,
#                     'first_max_value': 0.034,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 31,
#                     'arithmetic_mean': 0.018882,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-01',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 8,
#                     'first_max_value': 0.034,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.014208,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-02',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 13,
#                     'first_max_value': 0.03,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 25,
#                     'arithmetic_mean': 0.017208,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-02',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 20,
#                     'first_max_value': 0.027,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 25,
#                     'arithmetic_mean': 0.017208,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-02',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 20,
#                     'first_max_value': 0.027,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 25,
#                     'arithmetic_mean': 0.021765,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-02',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 20,
#                     'first_max_value': 0.027,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.016042,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-03',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 0,
#                     'first_max_value': 0.028,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 22,
#                     'arithmetic_mean': 0.012458,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-03',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 0,
#                     'first_max_value': 0.024,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 22,
#                     'arithmetic_mean': 0.012458,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-03',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 0,
#                     'first_max_value': 0.024,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 17,
#                     'arithmetic_mean': 0.008882,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-03',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 7,
#                     'first_max_value': 0.018,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.012875,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-04',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 22,
#                     'first_max_value': 0.026,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 23,
#                     'arithmetic_mean': 0.015208,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-04',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 22,
#                     'first_max_value': 0.025,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 23,
#                     'arithmetic_mean': 0.015208,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-04',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 22,
#                     'first_max_value': 0.025,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 23,
#                     'arithmetic_mean': 0.018176,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-04',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 22,
#                     'first_max_value': 0.025,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.023917,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-05',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 15,
#                     'first_max_value': 0.033,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 28,
#                     'arithmetic_mean': 0.021833,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-05',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 8,
#                     'first_max_value': 0.03,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 28,
#                     'arithmetic_mean': 0.021833,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-05',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 8,
#                     'first_max_value': 0.03,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 28,
#                     'arithmetic_mean': 0.019471,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-05',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 8,
#                     'first_max_value': 0.03,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.020625,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-06',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 13,
#                     'first_max_value': 0.034,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 29,
#                     'arithmetic_mean': 0.018875,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-06',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 11,
#                     'first_max_value': 0.031,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 29,
#                     'arithmetic_mean': 0.018875,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-06',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 11,
#                     'first_max_value': 0.031,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 29,
#                     'arithmetic_mean': 0.020412,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-06',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 11,
#                     'first_max_value': 0.031,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.012826,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-07',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 13,
#                     'first_max_value': 0.031,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 23,
#                     'observation_percent': 96.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 19,
#                     'arithmetic_mean': 0.014625,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-07',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 10,
#                     'first_max_value': 0.02,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 19,
#                     'arithmetic_mean': 0.014625,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-07',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 10,
#                     'first_max_value': 0.02,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 19,
#                     'arithmetic_mean': 0.018176,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-07',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 10,
#                     'first_max_value': 0.02,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.0145,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-08',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 12,
#                     'first_max_value': 0.031,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 19,
#                     'arithmetic_mean': 0.0125,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-08',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 5,
#                     'first_max_value': 0.02,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 19,
#                     'arithmetic_mean': 0.0125,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-08',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 5,
#                     'first_max_value': 0.02,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '420 34th Street N.E.,Washington, DC 20019',
#                     'site_number': '0041',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 17,
#                     'arithmetic_mean': 0.010412,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-01-08',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 7,
#                     'first_max_value': 0.018,
#                     'latitude': 38.895572,
#                     'local_site_name': 'RIVER TERRACE',
#                     'longitude': -76.958072,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
# ...
#                     'arithmetic_mean': 0.029625,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-28',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 11,
#                     'first_max_value': 0.039,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 36,
#                     'arithmetic_mean': 0.030882,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-28',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 11,
#                     'first_max_value': 0.039,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.03125,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-29',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 15,
#                     'first_max_value': 0.044,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 38,
#                     'arithmetic_mean': 0.029917,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-29',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 10,
#                     'first_max_value': 0.041,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 38,
#                     'arithmetic_mean': 0.029917,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-29',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 10,
#                     'first_max_value': 0.041,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 24,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 38,
#                     'arithmetic_mean': 0.029941,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-29',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 10,
#                     'first_max_value': 0.041,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 17,
#                     'observation_percent': 100.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': None,
#                     'arithmetic_mean': 0.035696,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-30',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 20,
#                     'first_max_value': 0.056,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 23,
#                     'observation_percent': 96.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 1-hour 1979',
#                     'sample_duration': '1 HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 44,
#                     'arithmetic_mean': 0.037474,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-30',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 14,
#                     'first_max_value': 0.048,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 19,
#                     'observation_percent': 79.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 1997',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 44,
#                     'arithmetic_mean': 0.037474,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-30',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 14,
#                     'first_max_value': 0.048,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 19,
#                     'observation_percent': 79.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-Hour 2008',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'Y'},
#                 {   'aqi': 44,
#                     'arithmetic_mean': 0.04475,
#                     'cbsa': 'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#                     'cbsa_code': '47900',
#                     'city': 'Washington',
#                     'county': 'District of Columbia',
#                     'county_code': '001',
#                     'date_local': '2020-06-30',
#                     'date_of_last_change': '2020-08-05',
#                     'datum': 'WGS84',
#                     'event_type': 'None',
#                     'first_max_hour': 14,
#                     'first_max_value': 0.048,
#                     'latitude': 38.970092,
#                     'local_site_name': 'Takoma Rec Center',
#                     'longitude': -77.016715,
#                     'method': 'INSTRUMENTAL - ULTRA VIOLET',
#                     'method_code': '047',
#                     'observation_count': 12,
#                     'observation_percent': 71.0,
#                     'parameter': 'Ozone',
#                     'parameter_code': '44201',
#                     'poc': 1,
#                     'pollutant_standard': 'Ozone 8-hour 2015',
#                     'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#                     'site_address': '301 Van Buren Street, N.W. Washington DC '
#                                     '20012',
#                     'site_number': '0050',
#                     'state': 'District Of Columbia',
#                     'state_code': '11',
#                     'units_of_measure': 'Parts per million',
#                     'validity_indicator': 'N'}],
#     'Header': [   {   'request_time': '2020-08-08T13:40:32-04:00',
#                       'rows': 2164,
#                       'status': 'Success',
#                       'url': 'https://aqs.epa.gov/data/api/dailyData/byState?email=trent.e.little%40gmail.com&key=sandmallard17&param=44201&bdate=20200101&edate=20200801&state=11'}]}

# %%
df = pd.DataFrame(state_list["Data"])


# with open(sta

# df = pd.read_json(state_list)
df.to_csv('../BootcampProject1/data.csv', index = None)

# df = pd.read_csv("data.csv")          
# df.head()
# name.head()
